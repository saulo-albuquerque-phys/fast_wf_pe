# %% [markdown]
# # INSTALLING LIBRARIES

# %% [markdown]
# WHEN RUNNING THIS FIRST LINE, YOU MIGHT NEED TO RESTART THE KERNEL. PLEASE DO RESTART IT AND RUN THIS SAME FIRST LINE AGAIN.

# %%
# !pip install tensorflow==2.12.0
# Out:
# Requirement already satisfied: tensorflow==2.12.0 in /usr/local/lib/python3.11/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.12.0) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.8.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.3.1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-264-2174954923.py in <cell line: 0>()
# ----> 1 get_ipython().system('pip install tensorflow==2.12.0')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     150
#     151     if pip_warn:
# --> 152       _pip.print_previous_import_warning(output)
#     153
#     154   def _send_error(self, exc_content):
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_pip.py in print_previous_import_warning(output)
#      54 def print_previous_import_warning(output):
#      55   """Prints a warning about previously imported packages."""
# ---> 56   packages = _previously_imported_packages(output)
#      57   if packages:
#      58     # display a list of packages using the colab-display-data mimetype, which
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_pip.py in _previously_imported_packages(pip_output)
#      48 def _previously_imported_packages(pip_output):
#      49   """List all previously imported packages from a pip install."""
# ---> 50   installed = set(_extract_toplevel_packages(pip_output))
#      51   return sorted(installed.intersection(set(sys.modules)))
#      52
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_pip.py in _extract_toplevel_packages(pip_output)
#      37   """Extract the list of toplevel packages associated with a pip install."""
#      38   toplevel = collections.defaultdict(set)
# ---> 39   for m, ps in importlib.metadata.packages_distributions().items():
#      40     for p in ps:
#      41       toplevel[p].add(m)
#
# /usr/lib/python3.11/importlib/metadata/__init__.py in packages_distributions()
#    1074     for dist in distributions():
#    1075         for pkg in _top_level_declared(dist) or _top_level_inferred(dist):
# -> 1076             pkg_to_dist[pkg].append(dist.metadata['Name'])
#    1077     return dict(pkg_to_dist)
#    1078
#
# /usr/local/lib/python3.11/dist-packages/importlib_metadata/__init__.py in metadata(self)
#     525
#     526         text = (
# --> 527             self.read_text('METADATA')
#     528             or self.read_text('PKG-INFO')
#     529             # This last clause is here to support old egg-info files.  Its
#
# /usr/local/lib/python3.11/dist-packages/importlib_metadata/__init__.py in read_text(self, filename)
#     996             PermissionError,
#     997         ):
# --> 998             return self._path.joinpath(filename).read_text(encoding='utf-8')
#     999
#    1000         return None
#
# /usr/lib/python3.11/pathlib.py in read_text(self, encoding, errors)
#    1056         """
#    1057         encoding = io.text_encoding(encoding)
# -> 1058         with self.open(mode='r', encoding=encoding, errors=errors) as f:
#    1059             return f.read()
#    1060
#
# /usr/lib/python3.11/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1042         if "b" not in mode:
#    1043             encoding = io.text_encoding(encoding)
# -> 1044         return io.open(self, mode, buffering, encoding, errors, newline)
#    1045
#    1046     def read_bytes(self):
#
# /usr/lib/python3.11/codecs.py in __init__(self, errors)
#
# KeyboardInterrupt:

# %%
# !pip install keras-tuner

# %% [markdown]
# # IMPORTING MLGW

# %% [markdown]
# WHEN RUNNING THIS FIRST LINE, YOU MIGHT NEED TO RESTART THE KERNEL. PLEASE DO RESTART IT AND RUN THIS SAME FIRST LINE AGAIN.

# %%
# !git clone https://github.com/stefanoschmidt1995/MLGW.git
# Out:
# Cloning into 'MLGW'...
# remote: Enumerating objects: 8154, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 8154 (delta 20), reused 15 (delta 15), pack-reused 8121 (from 3)
# Receiving objects: 100% (8154/8154), 678.00 MiB | 24.71 MiB/s, done.
# Resolving deltas: 100% (3744/3744), done.
# Updating files: 100% (1147/1147), done.

# %%
cd MLGW
# Out:
# /content/MLGW

# %%
# !python setup.py install
# Out:
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating mlgw.egg-info
# writing mlgw.egg-info/PKG-INFO
# writing dependency_links to mlgw.egg-info/dependency_links.txt
# writing requirements to mlgw.egg-info/requires.txt
# writing top-level names to mlgw.egg-info/top_level.txt
# writing manifest file 'mlgw.egg-info/SOURCES.txt'
# reading manifest file 'mlgw.egg-info/SOURCES.txt'
# writing manifest file 'mlgw.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/lib/mlgw
# copying mlgw/NN_model.py -> build/lib/mlgw
# copying mlgw/GW_helper.py -> build/lib/mlgw
# copying mlgw/__init__.py -> build/lib/mlgw
# copying mlgw/fit_model.py -> build/lib/mlgw
# copying mlgw/EM_MoE.py -> build/lib/mlgw
# copying mlgw/ML_routines.py -> build/lib/mlgw
# copying mlgw/GW_generator.py -> build/lib/mlgw
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'mlgw.TD_models.model_0' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'mlgw.TD_models.model_0' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'mlgw.TD_models.model_0' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'mlgw.TD_models.model_0' to be distributed and are
#         already explicitly excluding 'mlgw.TD_models.model_0' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'mlgw.TD_models.model_1' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'mlgw.TD_models.model_1' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'mlgw.TD_models.model_1' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'mlgw.TD_models.model_1' to be distributed and are
#         already explicitly excluding 'mlgw.TD_models.model_1' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'mlgw.TD_models.model_2' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'mlgw.TD_models.model_2' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'mlgw.TD_models.model_2' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'mlgw.TD_models.model_2' to be distributed and are
#         already explicitly excluding 'mlgw.TD_models.model_2' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'mlgw.TD_models.model_3' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'mlgw.TD_models.model_3' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'mlgw.TD_models.model_3' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'mlgw.TD_models.model_3' to be distributed and are
#         already explicitly excluding 'mlgw.TD_models.model_3' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# creating build/lib/mlgw/TD_models/model_0
# copying mlgw/TD_models/model_0/README -> build/lib/mlgw/TD_models/model_0
# creating build/lib/mlgw/TD_models/model_0/21
# copying mlgw/TD_models/model_0/21/Model_fit_info_01.txt -> build/lib/mlgw/TD_models/model_0/21
# copying mlgw/TD_models/model_0/21/Model_fit_info_0123.txt -> build/lib/mlgw/TD_models/model_0/21
# copying mlgw/TD_models/model_0/55/residual_coefficients_01 -> build/lib/mlgw/TD_models/model_0/55
# copying mlgw/TD_models/model_0/55/times.dat -> build/lib/mlgw/TD_models/model_0/55
# creating build/lib/mlgw/TD_models/model_1
# copying mlgw/TD_models/model_1/README -> build/lib/mlgw/TD_models/model_1
# creating build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_PCA_model -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_exp_0 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_exp_1 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_exp_2 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_exp_3 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_exp_4 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_exp_5 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_feat -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_gat_0 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_gat_1 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_gat_2 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_gat_3 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_gat_4 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/amp_gat_5 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/ph_PCA_model -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/ph_exp_0 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/ph_exp_1 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/ph_exp_2 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/ph_exp_3 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/ph_exp_4 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/ph_feat -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/ph_gat_0 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/ph_gat_1 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/ph_gat_2 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/ph_gat_3 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/ph_gat_4 -> build/lib/mlgw/TD_models/model_1/22
# copying mlgw/TD_models/model_1/22/times -> build/lib/mlgw/TD_models/model_1/22
# creating build/lib/mlgw/TD_models/model_2
# copying mlgw/TD_models/model_2/README -> build/lib/mlgw/TD_models/model_2
# creating build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_PCA_model -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_exp_0 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_exp_1 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_exp_2 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_exp_3 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_exp_4 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_exp_5 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_feat -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_gat_0 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_gat_1 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_gat_2 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_gat_3 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_gat_4 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/amp_gat_5 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/ph_PCA_model -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/ph_exp_0 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/ph_exp_1 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/ph_exp_2 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/ph_exp_3 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/ph_exp_4 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/ph_feat -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/ph_gat_0 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/ph_gat_1 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/ph_gat_2 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/ph_gat_3 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/ph_gat_4 -> build/lib/mlgw/TD_models/model_2/22
# copying mlgw/TD_models/model_2/22/times -> build/lib/mlgw/TD_models/model_2/22
# creating build/lib/mlgw/TD_models/model_3
# copying mlgw/TD_models/model_3/README -> build/lib/mlgw/TD_models/model_3
# creating build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/amp_PCA_model -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/amp_exp_0 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/amp_exp_1 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/amp_exp_2 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/amp_exp_3 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/amp_feat -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/amp_gat_0 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/amp_gat_1 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/amp_gat_2 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/amp_gat_3 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/ph_PCA_model -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/ph_exp_0 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/ph_exp_1 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/ph_exp_2 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/ph_exp_3 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/ph_feat -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/ph_gat_0 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/ph_gat_1 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/ph_gat_2 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/ph_gat_3 -> build/lib/mlgw/TD_models/model_3/22
# copying mlgw/TD_models/model_3/22/times -> build/lib/mlgw/TD_models/model_3/22
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/mlgw
# copying build/lib/mlgw/NN_model.py -> build/bdist.linux-x86_64/egg/mlgw
# copying build/lib/mlgw/GW_helper.py -> build/bdist.linux-x86_64/egg/mlgw
# copying build/lib/mlgw/__init__.py -> build/bdist.linux-x86_64/egg/mlgw
# copying build/lib/mlgw/fit_model.py -> build/bdist.linux-x86_64/egg/mlgw
# creating build/bdist.linux-x86_64/egg/mlgw/TD_models
# creating build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1
# creating build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/ph_PCA_model -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/ph_exp_0 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/ph_gat_4 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_gat_2 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_exp_4 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_feat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/ph_exp_1 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_gat_5 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/ph_exp_4 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/ph_gat_2 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_gat_1 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/ph_exp_2 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/ph_gat_1 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_gat_4 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/times -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_gat_0 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_exp_0 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_exp_1 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/ph_gat_0 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/ph_gat_3 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_exp_2 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_exp_3 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_gat_3 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_exp_5 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/ph_exp_3 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/ph_feat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/22/amp_PCA_model -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1/22
# copying build/lib/mlgw/TD_models/model_1/README -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_1
# creating build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2
# creating build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/ph_PCA_model -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/ph_exp_0 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/ph_gat_4 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_gat_2 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_exp_4 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_feat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/ph_exp_1 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_gat_5 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/ph_exp_4 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/ph_gat_2 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_gat_1 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/ph_exp_2 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/ph_gat_1 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_gat_4 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/times -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_gat_0 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_exp_0 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_exp_1 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/ph_gat_0 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/ph_gat_3 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_exp_2 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_exp_3 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_gat_3 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_exp_5 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/ph_exp_3 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/ph_feat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/22/amp_PCA_model -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2/22
# copying build/lib/mlgw/TD_models/model_2/README -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_2
# creating build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3
# creating build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/ph_PCA_model -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/ph_exp_0 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/amp_gat_2 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/amp_feat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/ph_exp_1 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/ph_gat_2 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/amp_gat_1 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/ph_exp_2 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/ph_gat_1 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/times -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/amp_gat_0 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/amp_exp_0 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/amp_exp_1 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/ph_gat_0 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/ph_gat_3 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/amp_exp_2 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/amp_exp_3 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/amp_gat_3 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/ph_exp_3 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/ph_feat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/22/amp_PCA_model -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3/22
# copying build/lib/mlgw/TD_models/model_3/README -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_3
# creating build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0
# creating build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/55
# copying build/lib/mlgw/TD_models/model_0/55/Model_fit_info_0123.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/55
# copying build/lib/mlgw/TD_models/model_0/55/ph_weights_01.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/55
# copying build/lib/mlgw/TD_models/model_0/55/ph_PCA_model.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/55
# copying build/lib/mlgw/TD_models/model_0/55/Model_fit_info_2345.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/55
# copying build/lib/mlgw/TD_models/model_0/55/times.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/55
# copying build/lib/mlgw/TD_models/model_0/55/ph_weights_01_residual.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/55
# copying build/lib/mlgw/TD_models/model_0/55/amp_weights_0123.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/55
# copying build/lib/mlgw/TD_models/model_0/55/Model_fit_info_01_residual.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/55
# copying build/lib/mlgw/TD_models/model_0/55/residual_coefficients_01 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/55
# copying build/lib/mlgw/TD_models/model_0/55/amp_PCA_model.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/55
# copying build/lib/mlgw/TD_models/model_0/55/ph_weights_2345.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/55
# copying build/lib/mlgw/TD_models/model_0/55/Model_fit_info_01.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/55
# creating build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/21
# copying build/lib/mlgw/TD_models/model_0/21/Model_fit_info_0123.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/21
# copying build/lib/mlgw/TD_models/model_0/21/ph_weights_01.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/21
# copying build/lib/mlgw/TD_models/model_0/21/ph_PCA_model.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/21
# copying build/lib/mlgw/TD_models/model_0/21/Model_fit_info_2345.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/21
# copying build/lib/mlgw/TD_models/model_0/21/times.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/21
# copying build/lib/mlgw/TD_models/model_0/21/ph_weights_01_residual.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/21
# copying build/lib/mlgw/TD_models/model_0/21/amp_weights_0123.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/21
# copying build/lib/mlgw/TD_models/model_0/21/Model_fit_info_01_residual.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/21
# copying build/lib/mlgw/TD_models/model_0/21/residual_coefficients_01 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/21
# copying build/lib/mlgw/TD_models/model_0/21/amp_PCA_model.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/21
# copying build/lib/mlgw/TD_models/model_0/21/ph_weights_2345.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/21
# copying build/lib/mlgw/TD_models/model_0/21/Model_fit_info_01.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/21
# creating build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/22
# copying build/lib/mlgw/TD_models/model_0/22/Model_fit_info_0123.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/22
# copying build/lib/mlgw/TD_models/model_0/22/ph_weights_01.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/22
# copying build/lib/mlgw/TD_models/model_0/22/ph_PCA_model.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/22
# copying build/lib/mlgw/TD_models/model_0/22/Model_fit_info_2345.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/22
# copying build/lib/mlgw/TD_models/model_0/22/times.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/22
# copying build/lib/mlgw/TD_models/model_0/22/ph_weights_01_residual.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/22
# copying build/lib/mlgw/TD_models/model_0/22/amp_weights_0123.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/22
# copying build/lib/mlgw/TD_models/model_0/22/Model_fit_info_01_residual.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/22
# copying build/lib/mlgw/TD_models/model_0/22/residual_coefficients_01 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/22
# copying build/lib/mlgw/TD_models/model_0/22/amp_PCA_model.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/22
# copying build/lib/mlgw/TD_models/model_0/22/ph_weights_2345.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/22
# copying build/lib/mlgw/TD_models/model_0/22/Model_fit_info_01.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/22
# copying build/lib/mlgw/TD_models/model_0/README -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0
# creating build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/33
# copying build/lib/mlgw/TD_models/model_0/33/Model_fit_info_0123.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/33
# copying build/lib/mlgw/TD_models/model_0/33/ph_weights_01.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/33
# copying build/lib/mlgw/TD_models/model_0/33/ph_PCA_model.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/33
# copying build/lib/mlgw/TD_models/model_0/33/Model_fit_info_2345.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/33
# copying build/lib/mlgw/TD_models/model_0/33/times.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/33
# copying build/lib/mlgw/TD_models/model_0/33/ph_weights_01_residual.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/33
# copying build/lib/mlgw/TD_models/model_0/33/amp_weights_0123.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/33
# copying build/lib/mlgw/TD_models/model_0/33/Model_fit_info_01_residual.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/33
# copying build/lib/mlgw/TD_models/model_0/33/residual_coefficients_01 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/33
# copying build/lib/mlgw/TD_models/model_0/33/amp_PCA_model.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/33
# copying build/lib/mlgw/TD_models/model_0/33/ph_weights_2345.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/33
# copying build/lib/mlgw/TD_models/model_0/33/Model_fit_info_01.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/33
# creating build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/44
# copying build/lib/mlgw/TD_models/model_0/44/Model_fit_info_0123.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/44
# copying build/lib/mlgw/TD_models/model_0/44/ph_weights_01.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/44
# copying build/lib/mlgw/TD_models/model_0/44/ph_PCA_model.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/44
# copying build/lib/mlgw/TD_models/model_0/44/Model_fit_info_2345.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/44
# copying build/lib/mlgw/TD_models/model_0/44/times.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/44
# copying build/lib/mlgw/TD_models/model_0/44/ph_weights_01_residual.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/44
# copying build/lib/mlgw/TD_models/model_0/44/amp_weights_0123.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/44
# copying build/lib/mlgw/TD_models/model_0/44/Model_fit_info_01_residual.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/44
# copying build/lib/mlgw/TD_models/model_0/44/residual_coefficients_01 -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/44
# copying build/lib/mlgw/TD_models/model_0/44/amp_PCA_model.dat -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/44
# copying build/lib/mlgw/TD_models/model_0/44/ph_weights_2345.keras -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/44
# copying build/lib/mlgw/TD_models/model_0/44/Model_fit_info_01.txt -> build/bdist.linux-x86_64/egg/mlgw/TD_models/model_0/44
# copying build/lib/mlgw/EM_MoE.py -> build/bdist.linux-x86_64/egg/mlgw
# copying build/lib/mlgw/ML_routines.py -> build/bdist.linux-x86_64/egg/mlgw
# copying build/lib/mlgw/GW_generator.py -> build/bdist.linux-x86_64/egg/mlgw
# byte-compiling build/bdist.linux-x86_64/egg/mlgw/NN_model.py to NN_model.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mlgw/GW_helper.py to GW_helper.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mlgw/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mlgw/fit_model.py to fit_model.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mlgw/EM_MoE.py to EM_MoE.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mlgw/ML_routines.py to ML_routines.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mlgw/GW_generator.py to GW_generator.cpython-311.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# installing scripts to build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# running install_scripts
# running build_scripts
# creating build/scripts-3.11
# copying and adjusting bin/mlgw_fit_NN -> build/scripts-3.11
# copying and adjusting bin/mlgw_generate_dataset -> build/scripts-3.11
# error: file '/content/MLGW/bin/mlgw_generate_angle_dataset' does not exist

# %%
# !sed -i '37d' mlgw/GW_generator.py

# %%
# !sed -i '39d' mlgw/GW_generator.py

# %%
# !sed -i '39d' mlgw/GW_generator.py

# %%
import mlgw

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import glob

# %%
from mlgw.GW_generator import mode_generator_NN

# %%
from mlgw.ML_routines import PCA_model, add_extra_features, jac_extra_features, augment_features

# %%
from scipy.special import factorial as fact

# %% [markdown]
# # IMPORTING AND SAVING MLGW DATA

# %% [markdown]
# ## DEFINING THE IMPORTING FUNCTIONS

# %%
"""
Module NN_model.py
==================

Loads the same Neural Network model to generate the reduced PCA coeffiecients of a WF (this time in jax). This is only related to the final saved model from the vanilla model. If you have trained a new model, consider disregarding this file completely
"""
import sys
import os
import numpy as np
import json
import matplotlib.pyplot as plt
from shutil import copy2
import glob

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

from keras_tuner import BayesianOptimization, HyperModel
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
from keras.optimizers import Nadam
from keras.callbacks import EarlyStopping, LearningRateScheduler
from keras import backend as backend
import jax
import jax.numpy as jnp
import jax.nn as jnn
from jax import random
from NN_model import mlgw_NN


from pathlib import Path

# %%
from NN_model import mlgw_NN

# %%
############################################################

class importing_saving_NN_from_mlgw:
  def __init__(self,folder="/content/MLGW/mlgw/TD_models/model_0/22/"):
    self.folder=folder
    self.amplitude_file=folder+"amp_weights_0123.keras"
    self.ph_01=folder+"ph_weights_01.keras"
    self.ph_res_01=folder+"ph_weights_01_residual.keras"
    self.ph_2345=folder+"ph_weights_2345.keras"
    self.ph_residual_coefficients_01=folder+"residual_coefficients_01"
    self.amp_model = mlgw_NN.load_from_file(self.amplitude_file)
    self.ph_01_model = mlgw_NN.load_from_file(self.ph_01)
    self.ph_res_01_model = mlgw_NN.load_from_file(self.ph_res_01)
    self.ph_2345_model = mlgw_NN.load_from_file(self.ph_2345)
    self.ph_residual_coef_01= np.loadtxt(self.ph_residual_coefficients_01)


  def saving_models(self,new_folder_name="new_data/"):
    folder=self.folder
    new_folder_path = os.path.join(folder, new_folder_name)  # Combine folder and new_folder_name
    os.makedirs(new_folder_path, exist_ok=True)
    j=0
    amp_model=self.amp_model
    ph_01_model=self.ph_01_model
    ph_res_01_model=self.ph_res_01_model
    ph_2345_model=self.ph_2345_model
    ph_residual_coefficients_01=self.ph_residual_coef_01
    np.savetxt(new_folder_path+f"ph_residual_coefficients_01.dat",ph_residual_coefficients_01)
    for i in amp_model.layers:
        print(i.name)
        a=i.get_weights()
        print(a)
        np.savetxt(new_folder_path+f"amp_model_weights_layer_{j}.dat",a[0])
        np.savetxt(new_folder_path+f"amp_model_bias_layer_{j}.dat",a[1])
        j+=1
    j=0
    for i in ph_01_model.layers:
        print(i.name)
        a=i.get_weights()
        print(a)
        np.savetxt(new_folder_path+f"ph_model_01_weights_layer_{j}.dat",a[0])
        np.savetxt(new_folder_path+f"ph_model_01_bias_layer_{j}.dat",a[1])
        j+=1
    j=0
    for i in ph_res_01_model.layers:
        print(i.name)
        a=i.get_weights()
        print(a)
        np.savetxt(new_folder_path+f"ph_res_model_01_weights_layer_{j}.dat",a[0])
        np.savetxt(new_folder_path+f"ph_res_model_01_bias_layer_{j}.dat",a[1])
        j+=1
    j=0
    for i in ph_2345_model.layers:
        print(i.name)
        a=i.get_weights()
        print(a)
        np.savetxt(new_folder_path+f"ph_model_2345_weights_layer_{j}.dat",a[0])
        np.savetxt(new_folder_path+f"ph_model_2345_bias_layer_{j}.dat",a[1])
        j+=1

# %%
class loading_NN_weights_bias:
  def __init__(self,folder="/content/MLGW/mlgw/TD_models/model_0/22/new_data/", n_amp_layers=2, n_ph_01_layers=3, n_res_ph_01_layers=6, n_ph_2345_layers=2):
    self.importing_folder=folder
    #loading hidden file
    self.residual_coefficients_01=np.loadtxt(self.importing_folder+f"ph_residual_coefficients_01.dat")
    # Initialize w and b as empty lists
    self.w_amp_0 = []
    self.b_amp_0 = []
    for j in range(n_amp_layers):  # or range(number_of_layers) if you have more layers
        self.w_amp_0.append(np.loadtxt(self.importing_folder+f"amp_model_weights_layer_{j}.dat"))
        self.b_amp_0.append(np.loadtxt(self.importing_folder+f"amp_model_bias_layer_{j}.dat"))
    # saving them
    self.w_amp=self.w_amp_0
    self.b_amp=self.b_amp_0
    # Initialize w and b as empty lists
    self.w_ph_01_0 = []
    self.b_ph_01_0 = []
    for j in range(n_ph_01_layers):  # or range(number_of_layers) if you have more layers
        self.w_ph_01_0.append(np.loadtxt(self.importing_folder+f"ph_model_01_weights_layer_{j}.dat"))
        self.b_ph_01_0.append(np.loadtxt(self.importing_folder+f"ph_model_01_bias_layer_{j}.dat"))
    # saving them
    self.w_ph_01=self.w_ph_01_0
    self.b_ph_01=self.b_ph_01_0
    # Initialize w and b as empty lists
    self.w_res_ph_01_0 = []
    self.b_res_ph_01_0 = []
    for j in range(n_res_ph_01_layers):  # or range(number_of_layers) if you have more layers
        self.w_res_ph_01_0.append(np.loadtxt(self.importing_folder+f"ph_res_model_01_weights_layer_{j}.dat"))
        self.b_res_ph_01_0.append(np.loadtxt(self.importing_folder+f"ph_res_model_01_bias_layer_{j}.dat"))
    # saving them
    self.w_res_ph_01=self.w_res_ph_01_0
    self.b_res_ph_01=self.b_res_ph_01_0
    # Initialize w and b as empty lists
    self.w_ph_2345_0 = []
    self.b_ph_2345_0 = []
    for j in range(n_ph_2345_layers):  # or range(number_of_layers) if you have more layers
        self.w_ph_2345_0.append(np.loadtxt(self.importing_folder+f"ph_model_2345_weights_layer_{j}.dat"))
        self.b_ph_2345_0.append(np.loadtxt(self.importing_folder+f"ph_model_2345_bias_layer_{j}.dat"))
    # saving them
    self.w_ph_2345=self.w_ph_2345_0
    self.b_ph_2345=self.b_ph_2345_0

# %% [markdown]
# ## IMPORTING THE MODEL

# %%
imp=importing_saving_NN_from_mlgw()

# %%
imp.saving_models()
# Out:
# dense
# [array([[ 9.65267941e-02,  1.09028447e+00, -2.14969041e-03,
#         -4.14372623e-01,  2.57698923e-01, -1.73163816e-01,
#         -1.22805059e+00, -7.61652812e-02, -3.27920407e-01,
#         -4.16113228e-01, -1.70777336e-01, -1.39981993e-02,
#          1.10110737e-01,  2.19841480e-01, -2.34207302e-01,
#         -1.98917389e+00, -3.32182378e-01, -1.14617154e-01,
#         -3.83362830e-01, -3.00611407e-01,  1.21554516e-01,
#          4.75011505e-02,  8.81764293e-02,  1.05482113e+00,
#         -8.21673349e-02, -1.54055297e-01, -3.53259519e-02,
#          5.74118719e-02, -8.97557497e-01, -1.53420344e-01,
#         -2.67519891e-01, -6.99042231e-02,  1.50734529e-01,
#          7.50119537e-02,  1.58603716e+00],
#        [ 5.04498601e-01,  2.51657665e-01,  8.15180659e-01,
#          7.69849002e-01, -6.31694555e+00, -2.83943653e+00,
#          2.41327190e+00, -5.64318001e-01,  7.81464517e-01,
#          1.47063196e+00, -2.89394021e-01,  1.70867074e+00,
#         -4.09223020e-01,  1.47685337e+00,  3.20123863e+00,
#         -1.03468955e-01,  2.02759886e+00, -3.92272019e+00,
#          1.77446556e+00, -1.23208022e+00,  5.02238989e-01,
#          7.92207837e-01,  2.20571551e-02,  6.75374150e-01,
#        [ 0.32402995, -0.22089191, -0.58305424, -1.2066687 ],
#        [ 0.30533975, -0.6142387 , -0.61448085, -1.3393375 ],
#        [ 0.38660073, -0.03352674, -0.7964226 ,  0.20227548],
#        [-0.2903298 ,  0.4249062 , -0.52722186,  0.44608295],
#        [ 0.3172821 , -0.64730006, -1.0706122 , -0.03509238],
#        [-0.46106797,  0.8326911 ,  2.7256289 ,  2.2218444 ],
#        [ 0.19284445, -1.1148449 , -0.7383683 , -0.9316685 ],
#        [-0.28594086,  1.2430135 ,  1.721377  ,  0.7262408 ],
#        [ 0.14450206,  0.1749123 , -0.7920237 , -2.127301  ],
#        [-0.45205334, -0.32021046,  0.5064528 ,  0.80112493],
#        [-0.5632391 , -0.25429896,  0.42135152,  0.4091361 ],
#        [ 0.1971875 , -0.593245  , -2.5689623 , -1.9696742 ],
#        [-0.05043594, -0.10925984,  1.6404002 , -0.07728212],
#        [ 0.53055936, -0.04217842, -0.3926217 , -0.9272788 ],
#        [ 0.01917596,  0.20859098,  0.29234856,  0.7447284 ]],
#       dtype=float32), array([ 0.03340075, -0.22865309, -0.13695112, -0.1373378 ], dtype=float32)]
# dense
# [array([[ 0.0687369 ,  0.19847643,  0.04496577, ...,  0.21478325,
#         -0.18666634,  0.18150857],
#        [-0.18215474,  0.2885867 ,  0.07018217, ..., -0.23826854,
#         -0.03490871, -0.00336748],
#        [ 0.03980754,  0.07346791,  0.22592898, ...,  0.01746891,
#         -0.01556765,  0.03486722],
#        ...,
#        [ 0.04230718, -0.033832  ,  0.29882246, ...,  0.21037579,
#         -0.01959933,  0.09483571],
#        [-0.01574428,  0.15942866,  0.00718311, ..., -0.1502385 ,
#         -0.27745846,  0.14384085],
#        [-0.3607393 ,  0.03094981, -0.01772813, ..., -0.04340085,
#          0.3187216 , -0.15444215]], dtype=float32), array([-0.09440476,  0.16745944,  0.15116462,  0.0308129 , -0.1277649 ,
#         0.0225737 , -0.05065066,  0.06857742,  0.10212111,  0.14270778,
#        -0.03188687,  0.04754646,  0.13954096,  0.00258093,  0.01727392,
#        -0.24864082,  0.12008016,  0.11367884,  0.12142362, -0.07865442,
#        -0.06138596, -0.10836813,  0.10929026,  0.08296341, -0.14967205,
#         0.07075548, -0.12659135,  0.12856251,  0.05834781,  0.12528987,
#         0.08711577, -0.13812198,  0.07075498,  0.15613545,  0.00982392,
#        -0.12602961,  0.05975407,  0.07894371, -0.03998931, -0.09041785,
#        -0.07906476, -0.06744399, -0.0055374 , -0.32580745, -0.23776224,
#         0.07063363,  0.12355326, -0.0663168 ,  0.09951314, -0.14834772],
#       dtype=float32)]
# dense_1
# [array([[ 0.01331889,  0.0279842 , -0.05893271, ...,  0.11906546,
#          0.05012034, -0.01422225],
#        [ 0.10580134,  0.13634273, -0.09182214, ...,  0.03743849,
#          0.2353606 ,  0.19765028],
#        [-0.4722677 ,  0.04244047,  0.01524449, ..., -0.07647803,
#          0.15083803,  0.1149358 ],
#        ...,
#        [ 0.24162893, -0.03944901,  0.1764782 , ..., -0.09640094,
#         -0.05708611, -0.04559185],
#        [-0.00899543,  0.0967803 ,  0.25255176, ...,  0.29816043,
#         -0.09732078,  0.01675829],
#        [-0.20001674, -0.01050464, -0.23704946, ...,  0.1695777 ,
#         -0.23615503, -0.21646582]], dtype=float32), array([-0.04257962, -0.0119667 , -0.00638609,  0.00551143,  0.01223583,
#         0.0111316 , -0.04104571,  0.02444495, -0.00772881, -0.0047633 ,
#        -0.03000504, -0.01138241,  0.00467283,  0.01875666, -0.03715073,
#        -0.01198396, -0.02936702, -0.01464907, -0.01649665,  0.00153277,
#        -0.02021055,  0.02356064, -0.01414502,  0.0134299 ,  0.0038149 ,
#        -0.02004399, -0.05634542,  0.01810349, -0.02804994,  0.0026031 ,
#        -0.02537554,  0.00532524, -0.01038095, -0.02418283,  0.00265316,
#        -0.01728419,  0.01170683,  0.02574666, -0.00722165,  0.00168203,
#        -0.02121451,  0.03314412, -0.00078224, -0.00036513, -0.00410268,
#        -0.02183765, -0.02299359,  0.01494464,  0.02725694,  0.00011608],
#       dtype=float32)]
# dense_2
# [array([[ 0.07675523, -0.5913588 ],
#        [ 0.24080692, -0.04231349],
#        [-0.3287312 ,  0.30077586],
#        [-0.11790213,  0.275402  ],
#        [-0.12597334, -0.0873742 ],
#        [-0.21367958, -0.10742917],
#        [ 0.21146925, -0.5366076 ],
#        [-0.15039304, -0.32153612],
#        [ 0.17864834,  0.36817068],
#        [-0.01635325, -0.27802467],
#        [ 0.0235709 , -0.48642483],
#        [ 0.13179567,  0.06101904],
#        [-0.0946205 ,  0.31468302],
#        [-0.36407635,  0.16065946],
#        [ 0.25056836,  0.39570642],
#        [ 0.17310284,  0.449625  ],
#        [ 0.41055983, -0.10629681],
#        [ 0.17984624,  0.28691906],
#        [ 0.23891486,  0.22881404],
#        [ 0.17004119, -0.06085748],
#        [ 0.03736977,  0.44476184],
#        [-0.08321402,  0.4017046 ],
#        [ 0.11745774, -0.37720957],
#        [-0.28719044, -0.27967608],
#        [-0.16861118, -0.38888824],
#        [ 0.3098041 ,  0.36823022],
#        [ 0.00791836, -0.23023653],
#        [-0.04475535,  0.09139768],
#        [-0.01232834, -0.43450162],
#        [-0.09202948, -0.4824326 ],
#        [ 0.15822826,  0.2945155 ],
#        [-0.07934104,  0.04301032],
#        [ 0.29412317, -0.03854223],
#        [ 0.06553566,  0.26769507],
#        [-0.1156102 , -0.22761267],
#        [ 0.35566133, -0.4251346 ],
#        [-0.364616  ,  0.12994884],
#        [-0.27109358,  0.36965367],
#        [ 0.07450043,  0.14038289],
#        [ 0.33173448,  0.3487116 ],
#        [ 0.12039848, -0.25733545],
#        [-0.17930672, -0.2947577 ],
#        [-0.15841205, -0.0418154 ],
#        [ 0.22001088, -0.31792945],
#        [-0.28994614,  0.16240132],
#        [ 0.14751212,  0.3883791 ],
#        [ 0.3716106 ,  0.45873028],
#        [-0.2607648 , -0.32811406],
#        [-0.06134729,  0.38856375],
#        [-0.17669567,  0.136957  ]], dtype=float32), array([-0.00071756, -0.02394904], dtype=float32)]
#         -5.04136562e-01,  1.75592542e+00, -6.95301116e-01,
#          5.75268507e-01, -4.24872696e-01,  1.16556607e-01,
#         -7.76968122e-01, -1.87693775e-01]], dtype=float32), array([ 0.23955242, -0.10696691,  0.27509427,  0.40985978, -0.0776763 ,
#         0.08894993, -0.70942223,  0.43805256,  0.02968166,  0.5078064 ,
#         0.04311787,  0.93917066, -0.80817676, -0.9906819 , -0.1008459 ,
#         0.56882197,  0.3125934 ,  0.21498273, -0.82629734, -2.430058  ,
#        -0.43037945, -0.21286829, -0.556779  , -0.4559828 , -0.59191495,
#         1.1280789 ,  0.1222607 ,  0.282762  , -0.712051  ,  0.59463656,
#         0.02264832,  1.007362  ,  0.9003099 , -0.8913877 , -0.19758347,
#         0.55902016,  0.00282974, -0.46370852, -2.7294564 , -0.16460736,
#         0.23711604,  1.1577934 , -0.53734815,  1.7691219 , -0.5614204 ,
#         0.18272978, -0.3566853 ,  0.42183003, -0.73062944,  0.01845115],
#       dtype=float32)]
# dense_1
# [array([[-0.5595528 , -0.8470349 ,  2.9615293 , ...,  0.632404  ,
#         -1.1126003 , -0.88274086],
#        [-0.20612727, -0.20992717,  0.43996218, ..., -0.01278795,
#         -2.9678662 , -0.5036296 ],
#        [-0.11303185,  0.00725217,  0.2920142 , ...,  0.00519442,
#          0.24704896,  0.7291488 ],
#        ...,
#        [-0.02902628, -0.15051818,  0.28960484, ..., -0.3481432 ,
#          0.11363278,  0.9927743 ],
#        [ 0.18201676, -0.01212452,  0.2996121 , ...,  0.2260263 ,
#         -0.16549307,  0.547476  ],
#        [ 0.10377512, -0.38971397, -0.02679904, ..., -0.3024324 ,
#          0.95019776,  0.41314733]], dtype=float32), array([-0.00916979,  0.05665471, -0.06620171, -0.10204323, -0.01638809,
#        -0.09141118, -0.14756112, -0.03816456, -0.11098783, -0.08846759,
#        -0.08385117, -0.09513146, -0.10046023,  0.01646438,  0.19781418,
#        -0.14938603, -0.15747777,  0.04537402, -0.06777786,  0.08087923,
#         0.0678815 ,  0.08292939, -0.08520306, -0.07149799,  0.11658748,
#        -0.13550143, -0.14444265,  0.04944051,  0.00237534,  0.07650222,
#        -0.17135079, -0.03716459, -0.04227407, -0.11871716, -0.13308187,
#        -0.14026424, -0.02091749, -0.1901088 , -0.02246394, -0.25756866,
#        -0.10313269, -0.18355207, -0.27568802,  0.00977426, -0.05897972,
#        -0.1140753 , -0.05694713,  0.11474524,  0.00924533, -0.06916994],
#       dtype=float32)]
# dense_2
# [array([[ 0.12988779, -0.5762724 ,  0.03860493, ...,  0.50372136,
#          0.36625656,  0.5986866 ],
#        [ 0.1653662 , -0.27486902,  0.01582345, ...,  0.79464185,
#          0.5014468 ,  0.57810575],
#        [-0.45934084,  0.00727477,  0.18323046, ..., -0.17431512,
#         -0.2976805 , -0.49157128],
#        ...,
#        [ 0.159129  , -0.26904172,  0.07250847, ...,  0.18057783,
#          0.4376344 ,  0.32531294],
#        [ 0.36024824, -0.09698251,  0.29443344, ...,  0.36452657,
#         -0.08798708,  0.45804846],
#        [ 0.00372591, -0.46792656,  0.18332028, ..., -0.10186999,
#          0.17895946, -0.23351039]], dtype=float32), array([-1.5018302e-01, -1.7516236e-01, -1.2550132e-02, -1.2132480e-01,
#        -1.5565677e-01, -1.4231911e-01, -1.5751328e-02, -2.1767938e-01,
#        -1.0469760e-01, -5.2464336e-02, -1.9984390e-01, -8.8497624e-02,
#        -4.2294640e-02, -1.2220474e-01, -2.0387052e-01, -9.6386693e-02,
#        -2.0202824e-01,  2.2951852e-01, -6.3897543e-02, -2.4906819e-01,
#        -2.7688789e-01, -1.6616839e-01, -2.5951171e-01, -1.6060351e-01,
#        -1.2626098e-01, -2.4610607e-01, -2.7451476e-02,  2.1071414e-02,
#        -2.2489968e-01,  2.4621930e-02, -2.7696980e-02, -1.6334094e-01,
#        -1.2553729e-01, -1.5209214e-01,  3.5790819e-01, -3.1035794e-02,
#        -9.5652969e-05, -1.7480336e-01,  3.3953279e-02,  1.3662554e-01,
#        -5.4783046e-02, -5.4396670e-03, -1.6702265e-01, -1.2718707e-01,
#        -6.0583297e-02, -2.1363898e-01, -9.5891625e-02, -1.3509940e-01,
#        -7.2639130e-02, -1.1677509e-01], dtype=float32)]
# dense_3
# [array([[-0.58591443, -0.4311967 , -0.14681183, ..., -0.70635605,
#         -0.08293866, -0.1696849 ],
#        [-0.00619674, -0.24933547, -0.2197529 , ...,  0.19154458,
#         -0.11135821,  0.7830396 ],
#        [-0.201631  ,  0.1334244 , -0.8996817 , ..., -0.32003897,
#         -0.33519804,  0.0563708 ],
#        ...,
#        [-0.81038374, -0.06088495, -0.4456237 , ..., -0.64747065,
#         -0.22743596,  0.23997928],
#        [-0.3452798 , -0.023514  , -0.6934448 , ..., -0.5524162 ,
#         -0.5095479 , -0.21301071],
#        [-0.45234558, -0.2326527 , -0.7563286 , ..., -0.46721014,
#          0.06782564, -0.08876319]], dtype=float32), array([-0.24144842, -0.12624966, -0.460774  , -0.1675928 , -0.21241868,
#         0.03917366, -0.47330964, -0.3032625 ,  0.20657808, -0.18972959,
#        -0.8579989 , -0.40578845, -0.03118172, -0.4417303 , -0.01314122,
#        -0.32994235, -0.09966061,  0.08318799, -0.21200342,  0.26160443,
#        -0.1601071 ,  0.12559389, -0.38895872, -0.08870561, -0.5155923 ,
#         0.0186085 , -0.14490789, -0.34408507,  0.08219597, -0.20629817,
#        -0.28469077, -0.61584973, -0.21472761, -0.09940624, -0.23282611,
#         0.05060747, -0.29580674, -0.17127144, -0.30913323, -0.34108666,
#         0.222332  ,  0.02508287, -0.09473827,  0.2547401 ,  0.46185997,
#        -0.05239207, -0.10452969, -0.1910707 , -0.15387315,  0.11373224],
#       dtype=float32)]
# dense_4
# [array([[-0.79111564, -0.2635211 , -0.8821124 , ...,  0.05286751,
#         -1.0499296 , -0.65398103],
#        [-0.6930491 , -0.3774826 , -1.1548387 , ..., -0.11414344,
#         -0.8110668 , -0.6402118 ],
#        [ 0.05791913,  1.846188  ,  1.0332068 , ..., -0.9740241 ,
#         -0.30491915,  1.7804682 ],
#        ...,
#        [ 0.0540165 , -0.3191735 ,  0.19163366, ..., -0.16271141,
#         -0.44585064, -0.42034966],
#        [ 0.059478  , -0.12171246,  0.635297  , ..., -0.40524858,
#          0.2157728 , -0.09388661],
#        [-0.7647527 ,  0.02910688, -0.4503058 , ..., -0.20097029,
#         -0.5908446 ,  0.1524104 ]], dtype=float32), array([-0.3205706 , -0.3681409 , -0.22991925, -0.5188633 , -0.22254303,
#        -0.15869091, -0.1698949 , -0.20068012, -0.15207423, -0.34899855,
#        -0.37280494, -0.11706677, -0.46972153, -0.5571684 , -0.22636911,
#        -0.1522117 , -0.11470724, -0.25492123, -0.26833242, -0.24289133,
#        -0.20887749, -0.48685768, -0.2323696 , -0.17007275, -0.1121064 ,
#        -0.1431148 , -0.1616994 , -0.28933084, -0.31476521, -0.7509449 ,
#        -0.4529189 , -0.22675657, -0.28036398, -0.21028693, -0.37572426,
#        -0.19470604, -0.6695912 , -0.47725642, -0.18460524, -0.523401  ,
#        -0.40364453, -0.3628294 , -0.41112   , -0.3799966 , -0.23893513,
#        -0.158525  , -0.20795502, -0.1753793 , -0.4495495 , -0.30932316],
#       dtype=float32)]
# dense_5
# [array([[ 0.02192705, -1.0490764 ],
#        [ 0.07503673,  0.22625212],
#        [ 0.03623452, -1.2371305 ],
#        [ 0.11566525,  1.52634   ],
#        [-0.090684  , -0.6768011 ],
#        [-0.23518056, -0.21876949],
#        [-0.23379593,  0.07061929],
#        [-0.19667836,  0.3515089 ],
#        [-0.26866317,  0.39099264],
#        [ 0.02751718, -0.9966575 ],
#        [ 0.07788254,  0.25976458],
#        [-0.05729092, -0.95057064],
#        [-0.03830578, -0.46579576],
#        [ 0.04082907, -0.5544884 ],
#        [ 0.15832447, -0.63827705],
#        [ 0.22594394, -0.8018293 ],
#        [-0.23046464, -0.27117762],
#        [-0.13449143,  1.3497924 ],
#        [-0.04486796, -0.6647652 ],
#        [-0.1624093 ,  0.11850238],
#        [ 0.18575805,  0.06469528],
#        [ 0.00713808, -0.58736765],
#        [-0.15189084, -0.12234675],
#        [ 0.23692639,  0.01197197],
#        [ 0.2501367 ,  0.18256067],
#        [-0.27350143,  0.34880087],
#        [-0.22139654, -0.2183566 ],
#        [-0.11475024, -0.0228888 ],
#        [ 0.15145646, -0.27956414],
#        [-0.04035895,  0.16850072],
#        [ 0.2648957 , -0.6373125 ],
#        [-0.16952673, -0.64458644],
#        [-0.06454479, -0.5453725 ],
#        [-0.1675718 , -0.24375664],
#        [-0.06922214, -0.21841128],
#        [-0.20111883, -0.15643118],
#        [-0.00559965, -0.46083808],
#        [ 0.02446646,  0.5122249 ],
#        [-0.08196958, -0.80627364],
#        [ 0.06094503,  0.16838822],
#        [-0.23440038,  1.2228185 ],
#        [ 0.0738322 , -0.31092757],
#        [-0.1589073 ,  0.936989  ],
#        [-0.09027509,  0.07788133],
#        [-0.12245923, -0.34570113],
#        [-0.24463265, -0.16916347],
#        [-0.19801027,  0.16875857],
#        [-0.17732884, -0.40549895],
#         -3.59365672e-01,  8.36299539e-01,  1.32484268e-02,
#          2.22764805e-01, -4.57614154e-01, -1.24986107e-02,
#         -4.91656035e-01,  9.73326936e-02, -7.13573098e-02,
#          7.42545351e-02, -9.83362436e-01, -3.42181586e-02,
#          5.57299219e-02, -2.59831518e-01,  2.74192959e-01,
#          7.44736940e-02,  5.22555411e-01]], dtype=float32), array([-1.0452474 ,  0.64258116,  1.2336676 ,  0.88471115, -0.7445057 ,
#         0.666114  ,  0.23107685,  0.49451864, -2.451528  ,  1.1728749 ,
#        -1.5441545 ,  3.2139654 ,  0.7683216 ,  5.45616   ,  0.4661931 ,
#        -1.1804185 ,  2.8509398 , -1.2805152 ,  0.80925035,  0.56919545,
#         0.7132176 , -2.2459662 ,  1.0482341 ,  1.4098039 ,  1.1650882 ,
#         0.70846754,  0.62634534, -2.283439  ,  1.119017  , -1.421526  ,
#         0.5823638 ,  0.71638477,  1.5101666 ,  0.17495733,  0.17052089,
#        -2.8321908 , -1.0208163 ,  1.1276286 ,  0.8899448 , -1.4913794 ,
#        -0.7576033 , -2.6989758 ,  0.8008383 , -0.24023981,  0.43755314,
#         0.22674222,  2.5580003 , -1.4694041 , -2.6332912 , -0.19798669],
#       dtype=float32)]
# dense_1
# [array([[ 4.44152921e-01, -1.37318954e-01,  3.33089113e-01,
#          3.16525131e-01],
#        [ 4.39868331e-01,  8.03162873e-01, -9.35390770e-01,
#          3.89325333e+00],
#        [-2.80231714e-01,  6.97546542e-01,  1.53182089e+00,
#          4.99447435e-01],
#        [-5.79381704e-01,  1.81499243e-01,  2.45214045e-01,
#         -2.54717320e-01],
#        [ 7.15656757e-01, -1.48190594e+00, -9.65692163e-01,
#          3.24103385e-01],
#        [-4.28531349e-01,  3.12399656e-01, -4.56489563e-01,
#         -1.05499685e-01],
#        [-4.71370906e-01, -8.00079167e-01, -2.99986899e-01,
#          4.82528716e-01],
#        [-8.62393558e-01, -1.19119227e-01,  5.96187115e-01,
#         -5.05389512e-01],
#        [ 5.23424506e-01,  2.29843855e+00, -3.68792355e-01,
#         -8.93219888e-01],
#        [-6.33169830e-01, -3.78236473e-01,  1.33146375e-01,
#          3.14924657e-01],
#        [ 8.35204542e-01, -1.16432428e+00, -2.04948759e+00,
#          1.27895558e+00],
#        [ 1.28706324e+00, -1.45985925e+00,  8.37581456e-01,
#          2.92267275e+00],
#        [-4.82976824e-01,  4.06348974e-01,  9.81288329e-02,
#         -3.50051343e-01],
#        [ 1.21209204e+00,  1.08279335e+00, -1.63759172e+00,
#          9.71952915e-01],
#        [-9.88220274e-02,  2.80510604e-01,  6.05660021e-01,
#         -1.18038011e+00],
#        [ 2.39096493e-01, -5.92753664e-02, -1.92770381e-02,
#          4.38883841e-01],
#        [-1.80907950e-01, -5.45573115e-01,  8.92798781e-01,
#         -3.20345569e+00],
#        [-2.03375697e-01, -1.44002795e+00,  4.42018270e-01,
#         -1.31622136e+00],
#        [-2.28458215e-02,  1.89850688e-01,  1.36141002e+00,
#         -2.11030555e+00],
#        [-3.54091972e-01,  3.37069273e-01,  7.55420253e-02,
#         -3.99813384e-01],
#        [-5.89170933e-01, -2.60286015e-02,  1.02172047e-01,
#         -5.98999143e-01],
#        [ 4.37326998e-01, -1.04921699e+00,  1.49607432e+00,
#          1.47274029e+00],
#        [-5.04782557e-01, -3.00294489e-01, -6.08942330e-01,
#          1.60045326e-02],
#        [ 5.32403111e-01,  2.31675935e+00,  1.35443556e+00,
#         -1.89738035e+00],
#        [ 1.39479542e+00, -1.29871440e+00, -1.40678555e-01,
#          7.40953684e-01],
#        [-4.55545455e-01, -3.73025462e-02, -5.38320363e-01,
#         -8.39803040e-01],
#        [-5.05200401e-03, -2.47183442e-01,  2.99188226e-01,
#         -7.86573052e-01],
#        [ 1.09521055e+00, -3.18293720e-01,  2.94000387e+00,
#          7.30850279e-01],
#        [-7.29023635e-01,  1.58033058e-01,  3.32362264e-01,
#         -9.80330110e-02],
#        [ 4.21154559e-01, -1.90441802e-01,  4.44610000e-01,
#          5.30787110e-01],
#        [-4.92099434e-01,  4.97933328e-01, -3.22310776e-01,
#          2.31146082e-01],
#        [-1.84658989e-01,  6.47963583e-01, -1.86113808e-02,
#          1.04234374e+00],
#        [-6.60844743e-01, -8.33951533e-01,  1.43515781e-01,
#          1.19075334e+00],
#        [-1.25542939e+00, -4.76346254e+00, -2.78127933e+00,
#          3.17571235e+00],
#        [-1.45035058e-01,  1.22429359e+00,  3.53529453e-01,
#          7.85274208e-01],
#        [-3.29872817e-01,  1.42456901e+00, -1.94267356e+00,
#          1.52371919e+00],
#        [ 2.88023382e-01, -5.14897406e-01, -1.83590919e-01,
#          5.55888653e-01],
#        [ 1.64799049e-01,  6.62934124e-01, -4.30631995e-01,
#         -1.55782831e+00],
#        [-6.43814743e-01,  6.98837757e-01, -2.33657017e-01,
#          2.00056970e-01],
#        [-3.88973296e-01, -3.99493873e-01,  7.47711062e-01,
#         -3.79172659e+00],
#        [ 3.81363660e-01, -3.79396021e-01, -6.44885749e-02,
#          1.00889850e+00],
#        [ 6.39248848e-01,  2.87832832e+00, -1.39820144e-01,
#          4.95519972e+00],
#        [ 4.69252735e-01,  2.58194476e-01, -1.60017252e+00,
#          1.28021646e+00],
#        [-2.62816757e-01, -3.98464501e-01,  7.97027051e-01,
#         -2.39260125e+00],
#        [-3.85511190e-01,  3.68243068e-01, -1.02881610e-03,
#         -5.86474717e-01],
#        [ 1.05547261e+00, -5.75893641e-01,  8.49580765e-01,
#         -1.05230963e+00],
#        [ 1.22942626e+00,  1.01663721e+00, -7.73367882e-01,
#         -2.71200329e-01],
#        [ 2.68201411e-01,  2.94379622e-01, -7.41488338e-01,
#         -7.48972118e-01],
#        [ 2.26790762e+00, -4.99025196e-01, -1.81148148e+00,
#         -2.62026429e+00],
#        [-7.12779224e-01, -2.00150639e-01,  1.50564298e-01,
#         -8.40639994e-02]], dtype=float32), array([-0.0145062 , -0.00312558,  0.11772173,  0.06428909], dtype=float32)]

# %%
loading_NN=loading_NN_weights_bias()
